# %% [markdown]
# <a href="https://colab.research.google.com/github/esracum/DronekitAutonomousFlight/blob/main/12_12_Backpropagation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Datasetin** **Oluşturulması**, **Train Test Split**

# %%
import csv

def create_train_test_datasets(train_filename, test_filename):
    # Dataset headers
    headers = ["x1", "x2", "y"]

    # Split data into train (odd results) and test (even results)
    train_data = []
    test_data = []

    for x1 in range(1, 11):  # Numbers 1 to 10
        for x2 in range(1, 11):  # Numbers 1 to 10
            y = x1 * x2
            if y % 2 != 0:  # Odd result
                train_data.append([x1, x2, y])
            else:  # Even result
                test_data.append([x1, x2, y])

    # Write train dataset
    with open(train_filename, mode="w", newline="") as train_file:
        writer = csv.writer(train_file)
        writer.writerow(headers)  # Write the headers
        writer.writerows(train_data)  # Write the rows

    print(f"Train dataset saved to {train_filename}")

    # Write test dataset
    with open(test_filename, mode="w", newline="") as test_file:
        writer = csv.writer(test_file)
        writer.writerow(headers)  # Write the headers
        writer.writerows(test_data)  # Write the rows

    print(f"Test dataset saved to {test_filename}")

# Create train and test datasets
create_train_test_datasets("train.csv", "test.csv")
# Out:
# Train dataset saved to train.csv
# Test dataset saved to test.csv

# %% [markdown]
# **Datasetin** **Normalizasyonu**

# %%
def normalize_and_save_train_test_datasets(train_filename, test_filename, normalized_train_filename, normalized_test_filename):
    # Normalize and save train dataset
    with open(train_filename, mode="r") as train_file:
        reader = csv.reader(train_file)
        headers = next(reader)  # Read headers
        train_data = list(reader)  # Read data

    normalized_train_data = []
    for row in train_data:
        x1, x2, y = map(float, row)
        x1_normalized = x1 / 10  # Normalize x1
        x2_normalized = x2 / 10  # Normalize x2
        y_normalized = y / 100  # Normalize y
        normalized_train_data.append([x1_normalized, x2_normalized, y_normalized])

    with open(normalized_train_filename, mode="w", newline="") as normalized_train_file:
        writer = csv.writer(normalized_train_file)
        writer.writerow(headers)  # Write headers
        writer.writerows(normalized_train_data)  # Write rows

    print(f"Normalized train dataset saved to {normalized_train_filename}")

    # Normalize and save test dataset
    with open(test_filename, mode="r") as test_file:
        reader = csv.reader(test_file)
        headers = next(reader)  # Read headers
        test_data = list(reader)  # Read data

    normalized_test_data = []
    for row in test_data:
        x1, x2, y = map(float, row)
        x1_normalized = x1 / 10  # Normalize x1
        x2_normalized = x2 / 10  # Normalize x2
        y_normalized = y / 100  # Normalize y
        normalized_test_data.append([x1_normalized, x2_normalized, y_normalized])

    with open(normalized_test_filename, mode="w", newline="") as normalized_test_file:
        writer = csv.writer(normalized_test_file)
        writer.writerow(headers)  # Write headers
        writer.writerows(normalized_test_data)  # Write rows

    print(f"Normalized test dataset saved to {normalized_test_filename}")

# Normalize and save train and test datasets
normalize_and_save_train_test_datasets("train.csv", "test.csv", "normalized_train.csv", "normalized_test.csv")
# Out:
# Normalized train dataset saved to normalized_train.csv
# Normalized test dataset saved to normalized_test.csv

# %% [markdown]
# **Modelin** **Oluşturulması**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
from sklearn.metrics import r2_score

# Normalized CSV dosyalarını oku
train_df = pd.read_csv('normalized_train.csv')
test_df = pd.read_csv('normalized_test.csv')

# Giriş ve çıkış verilerini ayır (train seti için)
X_train = train_df[['x1', 'x2']].values
y_train = train_df['y'].values

# Giriş ve çıkış verilerini ayır (test seti için)
X_test = test_df[['x1', 'x2']].values
y_test = test_df['y'].values

class DeepNeuralNetwork:
    def __init__(self, input_size, hidden_sizes, output_size, learning_rate=0.01):
        self.input_size = input_size
        self.hidden_sizes = hidden_sizes  # Gizli katmanların düğüm sayıları (liste)
        self.output_size = output_size
        self.learning_rate = learning_rate

        # Ağırlıklar ve bias'ları başlat
        self.weights = []
        self.biases = []
        layer_input_size = input_size

        # Gizli katmanlar için ağırlıklar ve bias'lar
        for hidden_size in hidden_sizes:
            self.weights.append(np.random.randn(layer_input_size, hidden_size) * np.sqrt(2. / layer_input_size))
            self.biases.append(np.zeros((1, hidden_size)))
            layer_input_size = hidden_size

        # Çıkış katmanı için ağırlık ve bias
        self.weights.append(np.random.randn(layer_input_size, output_size) * np.sqrt(2. / layer_input_size))
        self.biases.append(np.zeros((1, output_size)))

    def relu(self, x):
        return np.maximum(0, x)

    def relu_derivative(self, x):
        return np.where(x > 0, 1, 0)

    def sigmoid(self, x):
        return 1 / (1 + np.exp(-x))

    def sigmoid_derivative(self, x):
        return x * (1 - x)

    def forward(self, X):
        self.layer_inputs = []
        self.layer_outputs = []

        input_data = X
        for i in range(len(self.hidden_sizes)):
            self.layer_inputs.append(np.dot(input_data, self.weights[i]) + self.biases[i])
            input_data = self.relu(self.layer_inputs[-1])
            self.layer_outputs.append(input_data)

        # Çıkış katmanı
        self.output_input = np.dot(input_data, self.weights[-1]) + self.biases[-1]
        self.predicted_output = self.sigmoid(self.output_input)

    def backward(self, X, y):
        output_error = y - self.predicted_output
        output_delta = output_error * self.sigmoid_derivative(self.predicted_output)

        # Geri yayılım: Çıkış katmanından gizli katmanlara
        deltas = [output_delta]
        for i in reversed(range(len(self.hidden_sizes))):
            hidden_error = deltas[-1].dot(self.weights[i + 1].T)
            hidden_delta = hidden_error * self.relu_derivative(self.layer_outputs[i])
            deltas.append(hidden_delta)

        deltas = deltas[::-1]

        # Ağırlık ve bias güncellemeleri
        for i in range(len(self.hidden_sizes) + 1):
            self.weights[i] += self.layer_outputs[i - 1].T.dot(deltas[i]) * self.learning_rate if i > 0 else X.T.dot(deltas[i]) * self.learning_rate
            self.biases[i] += np.sum(deltas[i], axis=0, keepdims=True) * self.learning_rate

    def train(self, X_train, y_train, X_val, y_val, epochs):
        self.train_cost = []
        self.val_cost = []
        for epoch in range(epochs):
            self.forward(X_train)
            self.backward(X_train, y_train)

            # Eğitim kaybı (Mean Squared Error)
            train_cost = np.mean((y_train - self.predicted_output) ** 2)
            self.train_cost.append(train_cost)

            # Doğrulama kaybı
            self.forward(X_val)
            val_cost = np.mean((y_val - self.predicted_output) ** 2)
            self.val_cost.append(val_cost)

            if epoch % 100 == 0:
                print(f"Epoch {epoch}/{epochs}, Eğitim Cost: {train_cost:.4f}, Doğrulama Cost: {val_cost:.4f}")

    def predict(self, X):
        self.forward(X)
        return self.predicted_output

# Hiperparametre arama fonksiyonu
def find_best_hyperparameters(X_train, y_train, X_val, y_val, learning_rates, epochs_values, hidden_sizes):
    best_cost = float('inf')
    best_hyperparameters = {}

    for learning_rate in learning_rates:
        for epochs in epochs_values:
            for hidden_size in hidden_sizes:
                model = DeepNeuralNetwork(input_size=2, hidden_sizes=[hidden_size], output_size=1, learning_rate=learning_rate)
                model.train(X_train, y_train.reshape(-1, 1), X_val, y_val.reshape(-1, 1), epochs)

                # En iyi hiperparametreyi doğrulama kaybına göre seç
                val_cost = model.val_cost[-1]
                if val_cost < best_cost:
                    best_cost = val_cost
                    best_hyperparameters = {'learning_rate': learning_rate, 'epochs': epochs, 'hidden_size': hidden_size}

    return best_hyperparameters

# Hiperparametre arama için değerler
learning_rates = [0.001, 0.01, 0.1]
epochs_values = [500, 1500, 2500]
hidden_sizes = [2, 4, 8]

# Eğitim ve doğrulama setlerini belirle
X_val, y_val = X_test, y_test

# En iyi hiperparametreleri bul
best_hyperparameters = find_best_hyperparameters(X_train, y_train, X_val, y_val, learning_rates, epochs_values, hidden_sizes)

# En iyi hiperparametrelerle modeli tekrar eğit
best_model = DeepNeuralNetwork(input_size=2, hidden_sizes=[best_hyperparameters['hidden_size']],
                               output_size=1, learning_rate=best_hyperparameters['learning_rate'])
best_model.train(X_train, y_train.reshape(-1, 1), X_val, y_val.reshape(-1, 1), best_hyperparameters['epochs'])

# Test setini değerlendir
predictions = best_model.predict(X_test)
test_cost = np.mean((predictions - y_test.reshape(-1, 1)) ** 2)
print(f'En İyi Modelin Test Cost\'u: {test_cost:.4f}')
print(f'En İyi Hiperparametreler: {best_hyperparameters}')

# Eğitim ve Doğrulama Kayıp Grafiği
plt.plot(best_model.train_cost, label='Eğitim Cost')
plt.plot(best_model.val_cost, label='Doğrulama Cost')
plt.title("Eğitim ve Doğrulama Cost Değerleri")
plt.xlabel("Epochs")
plt.ylabel("Cost")
plt.legend()
plt.show()

# Gerçek Değerler vs Tahminler Grafiği
plt.scatter(y_test, predictions)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linewidth=2)  # y = x doğrusu
plt.title("Gerçek Değerler vs Tahmin Edilen Değerler")
plt.xlabel("Gerçek Değerler")
plt.ylabel("Tahmin Edilen Değerler")
plt.show()

# R² Skoru
r2 = r2_score(y_test, predictions)
print(f"R² Skoru: {r2:.4f}")

# Modeli kaydet
with open('best_model.pkl', 'wb') as model_file:
    pickle.dump(best_model, model_file)
# Out:
# Epoch 0/500, Eğitim Cost: 0.1089, Doğrulama Cost: 0.0912
# Epoch 100/500, Eğitim Cost: 0.0922, Doğrulama Cost: 0.0796
# Epoch 200/500, Eğitim Cost: 0.0801, Doğrulama Cost: 0.0718
# Epoch 300/500, Eğitim Cost: 0.0714, Doğrulama Cost: 0.0667
# Epoch 400/500, Eğitim Cost: 0.0652, Doğrulama Cost: 0.0634
# Epoch 0/500, Eğitim Cost: 0.1806, Doğrulama Cost: 0.1513
# Epoch 100/500, Eğitim Cost: 0.0982, Doğrulama Cost: 0.0819
# Epoch 200/500, Eğitim Cost: 0.0690, Doğrulama Cost: 0.0601
# Epoch 300/500, Eğitim Cost: 0.0572, Doğrulama Cost: 0.0530
# Epoch 400/500, Eğitim Cost: 0.0515, Doğrulama Cost: 0.0504
# Epoch 0/500, Eğitim Cost: 0.1981, Doğrulama Cost: 0.1667
# Epoch 100/500, Eğitim Cost: 0.1169, Doğrulama Cost: 0.0972
# Epoch 200/500, Eğitim Cost: 0.0815, Doğrulama Cost: 0.0693
# Epoch 300/500, Eğitim Cost: 0.0651, Doğrulama Cost: 0.0581
# Epoch 400/500, Eğitim Cost: 0.0565, Doğrulama Cost: 0.0532
# Epoch 0/1500, Eğitim Cost: 0.1062, Doğrulama Cost: 0.0894
# Epoch 100/1500, Eğitim Cost: 0.0834, Doğrulama Cost: 0.0746
# Epoch 200/1500, Eğitim Cost: 0.0702, Doğrulama Cost: 0.0675
# Epoch 300/1500, Eğitim Cost: 0.0626, Doğrulama Cost: 0.0644
# Epoch 400/1500, Eğitim Cost: 0.0580, Doğrulama Cost: 0.0632
# Epoch 500/1500, Eğitim Cost: 0.0551, Doğrulama Cost: 0.0629
# Epoch 600/1500, Eğitim Cost: 0.0532, Doğrulama Cost: 0.0629
# Epoch 700/1500, Eğitim Cost: 0.0519, Doğrulama Cost: 0.0630
# Epoch 800/1500, Eğitim Cost: 0.0510, Doğrulama Cost: 0.0631
# Epoch 900/1500, Eğitim Cost: 0.0502, Doğrulama Cost: 0.0632
# Epoch 1000/1500, Eğitim Cost: 0.0496, Doğrulama Cost: 0.0632
# Epoch 1100/1500, Eğitim Cost: 0.0490, Doğrulama Cost: 0.0631
# Epoch 1200/1500, Eğitim Cost: 0.0485, Doğrulama Cost: 0.0629
# Epoch 1300/1500, Eğitim Cost: 0.0481, Doğrulama Cost: 0.0626
# Epoch 1400/1500, Eğitim Cost: 0.0476, Doğrulama Cost: 0.0623
# Epoch 0/1500, Eğitim Cost: 0.1347, Doğrulama Cost: 0.1107
# Epoch 100/1500, Eğitim Cost: 0.1015, Doğrulama Cost: 0.0850
# Epoch 200/1500, Eğitim Cost: 0.0822, Doğrulama Cost: 0.0716
# Epoch 300/1500, Eğitim Cost: 0.0705, Doğrulama Cost: 0.0644
# Epoch 400/1500, Eğitim Cost: 0.0631, Doğrulama Cost: 0.0604
# Epoch 500/1500, Eğitim Cost: 0.0581, Doğrulama Cost: 0.0581
# Epoch 600/1500, Eğitim Cost: 0.0546, Doğrulama Cost: 0.0568
# Epoch 700/1500, Eğitim Cost: 0.0521, Doğrulama Cost: 0.0560
# Epoch 800/1500, Eğitim Cost: 0.0502, Doğrulama Cost: 0.0556
# Epoch 900/1500, Eğitim Cost: 0.0487, Doğrulama Cost: 0.0553
# Epoch 1000/1500, Eğitim Cost: 0.0476, Doğrulama Cost: 0.0551
# Epoch 1100/1500, Eğitim Cost: 0.0466, Doğrulama Cost: 0.0549
# Epoch 1200/1500, Eğitim Cost: 0.0458, Doğrulama Cost: 0.0548
# Epoch 1300/1500, Eğitim Cost: 0.0451, Doğrulama Cost: 0.0546
# Epoch 1400/1500, Eğitim Cost: 0.0445, Doğrulama Cost: 0.0544
# Epoch 0/1500, Eğitim Cost: 0.0904, Doğrulama Cost: 0.1202
# Epoch 100/1500, Eğitim Cost: 0.0879, Doğrulama Cost: 0.1164
# Epoch 200/1500, Eğitim Cost: 0.0854, Doğrulama Cost: 0.1123
# Epoch 300/1500, Eğitim Cost: 0.0828, Doğrulama Cost: 0.1079
# Epoch 400/1500, Eğitim Cost: 0.0802, Doğrulama Cost: 0.1035
# Epoch 500/1500, Eğitim Cost: 0.0776, Doğrulama Cost: 0.0991
# Epoch 600/1500, Eğitim Cost: 0.0752, Doğrulama Cost: 0.0950
# Epoch 700/1500, Eğitim Cost: 0.0728, Doğrulama Cost: 0.0911
# Epoch 800/1500, Eğitim Cost: 0.0706, Doğrulama Cost: 0.0876
# Epoch 900/1500, Eğitim Cost: 0.0685, Doğrulama Cost: 0.0843
# Epoch 1000/1500, Eğitim Cost: 0.0665, Doğrulama Cost: 0.0813
# Epoch 1100/1500, Eğitim Cost: 0.0645, Doğrulama Cost: 0.0786
# Epoch 1200/1500, Eğitim Cost: 0.0627, Doğrulama Cost: 0.0761
# Epoch 1300/1500, Eğitim Cost: 0.0609, Doğrulama Cost: 0.0737
# Epoch 1400/1500, Eğitim Cost: 0.0591, Doğrulama Cost: 0.0715
# Epoch 0/2500, Eğitim Cost: 0.2408, Doğrulama Cost: 0.2084
# Epoch 100/2500, Eğitim Cost: 0.1379, Doğrulama Cost: 0.1159
# Epoch 200/2500, Eğitim Cost: 0.0903, Doğrulama Cost: 0.0762
# Epoch 300/2500, Eğitim Cost: 0.0692, Doğrulama Cost: 0.0607
# Epoch 400/2500, Eğitim Cost: 0.0585, Doğrulama Cost: 0.0543
# Epoch 500/2500, Eğitim Cost: 0.0525, Doğrulama Cost: 0.0513
# Epoch 600/2500, Eğitim Cost: 0.0488, Doğrulama Cost: 0.0498
# Epoch 700/2500, Eğitim Cost: 0.0462, Doğrulama Cost: 0.0489
# Epoch 800/2500, Eğitim Cost: 0.0443, Doğrulama Cost: 0.0483
# Epoch 900/2500, Eğitim Cost: 0.0428, Doğrulama Cost: 0.0477
# Epoch 1000/2500, Eğitim Cost: 0.0415, Doğrulama Cost: 0.0472
# Epoch 1100/2500, Eğitim Cost: 0.0405, Doğrulama Cost: 0.0466
# Epoch 1200/2500, Eğitim Cost: 0.0395, Doğrulama Cost: 0.0460
# Epoch 1300/2500, Eğitim Cost: 0.0386, Doğrulama Cost: 0.0454
# Epoch 1400/2500, Eğitim Cost: 0.0378, Doğrulama Cost: 0.0448
# Epoch 1500/2500, Eğitim Cost: 0.0370, Doğrulama Cost: 0.0441
# Epoch 1600/2500, Eğitim Cost: 0.0362, Doğrulama Cost: 0.0434
# Epoch 1700/2500, Eğitim Cost: 0.0355, Doğrulama Cost: 0.0427
# Epoch 1800/2500, Eğitim Cost: 0.0348, Doğrulama Cost: 0.0420
# Epoch 1900/2500, Eğitim Cost: 0.0341, Doğrulama Cost: 0.0412
# Epoch 2000/2500, Eğitim Cost: 0.0334, Doğrulama Cost: 0.0405
# Epoch 2100/2500, Eğitim Cost: 0.0328, Doğrulama Cost: 0.0397
# Epoch 2200/2500, Eğitim Cost: 0.0321, Doğrulama Cost: 0.0390
# Epoch 2300/2500, Eğitim Cost: 0.0315, Doğrulama Cost: 0.0382
# Epoch 2400/2500, Eğitim Cost: 0.0309, Doğrulama Cost: 0.0375
# Epoch 0/2500, Eğitim Cost: 0.0868, Doğrulama Cost: 0.0994
# Epoch 100/2500, Eğitim Cost: 0.0829, Doğrulama Cost: 0.0981
# Epoch 200/2500, Eğitim Cost: 0.0801, Doğrulama Cost: 0.0970
# Epoch 300/2500, Eğitim Cost: 0.0778, Doğrulama Cost: 0.0960
# Epoch 400/2500, Eğitim Cost: 0.0759, Doğrulama Cost: 0.0950
# Epoch 500/2500, Eğitim Cost: 0.0742, Doğrulama Cost: 0.0940
# Epoch 600/2500, Eğitim Cost: 0.0727, Doğrulama Cost: 0.0929
# Epoch 700/2500, Eğitim Cost: 0.0714, Doğrulama Cost: 0.0918
# Epoch 800/2500, Eğitim Cost: 0.0702, Doğrulama Cost: 0.0906
# Epoch 900/2500, Eğitim Cost: 0.0690, Doğrulama Cost: 0.0894
# Epoch 1000/2500, Eğitim Cost: 0.0679, Doğrulama Cost: 0.0883
# Epoch 1100/2500, Eğitim Cost: 0.0668, Doğrulama Cost: 0.0871
# Epoch 1200/2500, Eğitim Cost: 0.0658, Doğrulama Cost: 0.0859
# Epoch 1300/2500, Eğitim Cost: 0.0649, Doğrulama Cost: 0.0848
# Epoch 1400/2500, Eğitim Cost: 0.0639, Doğrulama Cost: 0.0836
# Epoch 1500/2500, Eğitim Cost: 0.0630, Doğrulama Cost: 0.0825
# Epoch 1600/2500, Eğitim Cost: 0.0622, Doğrulama Cost: 0.0814
# Epoch 1700/2500, Eğitim Cost: 0.0614, Doğrulama Cost: 0.0804
# Epoch 1800/2500, Eğitim Cost: 0.0606, Doğrulama Cost: 0.0794
# Epoch 1900/2500, Eğitim Cost: 0.0598, Doğrulama Cost: 0.0784
# Epoch 2000/2500, Eğitim Cost: 0.0591, Doğrulama Cost: 0.0774
# Epoch 2100/2500, Eğitim Cost: 0.0584, Doğrulama Cost: 0.0765
# Epoch 2200/2500, Eğitim Cost: 0.0577, Doğrulama Cost: 0.0756
# Epoch 2300/2500, Eğitim Cost: 0.0570, Doğrulama Cost: 0.0747
# Epoch 2400/2500, Eğitim Cost: 0.0564, Doğrulama Cost: 0.0739
# Epoch 0/2500, Eğitim Cost: 0.1200, Doğrulama Cost: 0.0995
# Epoch 100/2500, Eğitim Cost: 0.0860, Doğrulama Cost: 0.0789
# Epoch 200/2500, Eğitim Cost: 0.0734, Doğrulama Cost: 0.0740
# Epoch 300/2500, Eğitim Cost: 0.0674, Doğrulama Cost: 0.0727
# Epoch 400/2500, Eğitim Cost: 0.0638, Doğrulama Cost: 0.0719
# Epoch 500/2500, Eğitim Cost: 0.0612, Doğrulama Cost: 0.0710
# Epoch 600/2500, Eğitim Cost: 0.0591, Doğrulama Cost: 0.0699
# Epoch 700/2500, Eğitim Cost: 0.0572, Doğrulama Cost: 0.0686
# Epoch 800/2500, Eğitim Cost: 0.0555, Doğrulama Cost: 0.0671
# Epoch 900/2500, Eğitim Cost: 0.0539, Doğrulama Cost: 0.0655
# Epoch 1000/2500, Eğitim Cost: 0.0524, Doğrulama Cost: 0.0638
# Epoch 1100/2500, Eğitim Cost: 0.0508, Doğrulama Cost: 0.0621
# Epoch 1200/2500, Eğitim Cost: 0.0494, Doğrulama Cost: 0.0604
# Epoch 1300/2500, Eğitim Cost: 0.0479, Doğrulama Cost: 0.0586
# Epoch 1400/2500, Eğitim Cost: 0.0466, Doğrulama Cost: 0.0570
# Epoch 1500/2500, Eğitim Cost: 0.0452, Doğrulama Cost: 0.0553
# Epoch 1600/2500, Eğitim Cost: 0.0439, Doğrulama Cost: 0.0537
# Epoch 1700/2500, Eğitim Cost: 0.0427, Doğrulama Cost: 0.0521
# Epoch 1800/2500, Eğitim Cost: 0.0414, Doğrulama Cost: 0.0506
# Epoch 1900/2500, Eğitim Cost: 0.0402, Doğrulama Cost: 0.0491
# Epoch 2000/2500, Eğitim Cost: 0.0390, Doğrulama Cost: 0.0476
# Epoch 2100/2500, Eğitim Cost: 0.0379, Doğrulama Cost: 0.0461
# Epoch 2200/2500, Eğitim Cost: 0.0368, Doğrulama Cost: 0.0447
# Epoch 2300/2500, Eğitim Cost: 0.0357, Doğrulama Cost: 0.0434
# Epoch 2400/2500, Eğitim Cost: 0.0346, Doğrulama Cost: 0.0421
# Epoch 0/500, Eğitim Cost: 0.3549, Doğrulama Cost: 0.3043
# Epoch 100/500, Eğitim Cost: 0.0610, Doğrulama Cost: 0.0718
# Epoch 200/500, Eğitim Cost: 0.0488, Doğrulama Cost: 0.0666
# Epoch 300/500, Eğitim Cost: 0.0474, Doğrulama Cost: 0.0655
# Epoch 400/500, Eğitim Cost: 0.0467, Doğrulama Cost: 0.0648
# Epoch 0/500, Eğitim Cost: 0.1429, Doğrulama Cost: 0.1139
# Epoch 100/500, Eğitim Cost: 0.0432, Doğrulama Cost: 0.0521
# Epoch 200/500, Eğitim Cost: 0.0354, Doğrulama Cost: 0.0457
# Epoch 300/500, Eğitim Cost: 0.0280, Doğrulama Cost: 0.0365
# Epoch 400/500, Eğitim Cost: 0.0215, Doğrulama Cost: 0.0282
# Epoch 0/500, Eğitim Cost: 0.0837, Doğrulama Cost: 0.0825
# Epoch 100/500, Eğitim Cost: 0.0556, Doğrulama Cost: 0.0649
# Epoch 200/500, Eğitim Cost: 0.0399, Doğrulama Cost: 0.0466
# Epoch 300/500, Eğitim Cost: 0.0286, Doğrulama Cost: 0.0331
# Epoch 400/500, Eğitim Cost: 0.0203, Doğrulama Cost: 0.0234
# Epoch 0/1500, Eğitim Cost: 0.0997, Doğrulama Cost: 0.0826
# Epoch 100/1500, Eğitim Cost: 0.0403, Doğrulama Cost: 0.0512
# Epoch 200/1500, Eğitim Cost: 0.0320, Doğrulama Cost: 0.0444
# Epoch 300/1500, Eğitim Cost: 0.0274, Doğrulama Cost: 0.0401
# Epoch 400/1500, Eğitim Cost: 0.0236, Doğrulama Cost: 0.0355
# Epoch 500/1500, Eğitim Cost: 0.0201, Doğrulama Cost: 0.0308
# Epoch 600/1500, Eğitim Cost: 0.0169, Doğrulama Cost: 0.0265
# Epoch 700/1500, Eğitim Cost: 0.0142, Doğrulama Cost: 0.0228
# Epoch 800/1500, Eğitim Cost: 0.0118, Doğrulama Cost: 0.0196
# Epoch 900/1500, Eğitim Cost: 0.0099, Doğrulama Cost: 0.0170
# Epoch 1000/1500, Eğitim Cost: 0.0083, Doğrulama Cost: 0.0148
# Epoch 1100/1500, Eğitim Cost: 0.0070, Doğrulama Cost: 0.0130
# Epoch 1200/1500, Eğitim Cost: 0.0060, Doğrulama Cost: 0.0115
# Epoch 1300/1500, Eğitim Cost: 0.0052, Doğrulama Cost: 0.0103
# Epoch 1400/1500, Eğitim Cost: 0.0045, Doğrulama Cost: 0.0093
# Epoch 0/1500, Eğitim Cost: 0.0919, Doğrulama Cost: 0.1256
# Epoch 100/1500, Eğitim Cost: 0.0673, Doğrulama Cost: 0.0875
# Epoch 200/1500, Eğitim Cost: 0.0458, Doğrulama Cost: 0.0573
# Epoch 300/1500, Eğitim Cost: 0.0303, Doğrulama Cost: 0.0377
# Epoch 400/1500, Eğitim Cost: 0.0195, Doğrulama Cost: 0.0243
# Epoch 500/1500, Eğitim Cost: 0.0125, Doğrulama Cost: 0.0156
# Epoch 600/1500, Eğitim Cost: 0.0082, Doğrulama Cost: 0.0103
# Epoch 700/1500, Eğitim Cost: 0.0055, Doğrulama Cost: 0.0070
# Epoch 800/1500, Eğitim Cost: 0.0038, Doğrulama Cost: 0.0050
# Epoch 900/1500, Eğitim Cost: 0.0028, Doğrulama Cost: 0.0037
# Epoch 1000/1500, Eğitim Cost: 0.0021, Doğrulama Cost: 0.0029
# Epoch 1100/1500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0024
# Epoch 1200/1500, Eğitim Cost: 0.0014, Doğrulama Cost: 0.0020
# Epoch 1300/1500, Eğitim Cost: 0.0012, Doğrulama Cost: 0.0018
# Epoch 1400/1500, Eğitim Cost: 0.0011, Doğrulama Cost: 0.0016
# Epoch 0/1500, Eğitim Cost: 0.1888, Doğrulama Cost: 0.1492
# Epoch 100/1500, Eğitim Cost: 0.0309, Doğrulama Cost: 0.0354
# Epoch 200/1500, Eğitim Cost: 0.0215, Doğrulama Cost: 0.0260
# Epoch 300/1500, Eğitim Cost: 0.0152, Doğrulama Cost: 0.0189
# Epoch 400/1500, Eğitim Cost: 0.0107, Doğrulama Cost: 0.0134
# Epoch 500/1500, Eğitim Cost: 0.0076, Doğrulama Cost: 0.0096
# Epoch 600/1500, Eğitim Cost: 0.0055, Doğrulama Cost: 0.0070
# Epoch 700/1500, Eğitim Cost: 0.0041, Doğrulama Cost: 0.0052
# Epoch 800/1500, Eğitim Cost: 0.0031, Doğrulama Cost: 0.0040
# Epoch 900/1500, Eğitim Cost: 0.0024, Doğrulama Cost: 0.0032
# Epoch 1000/1500, Eğitim Cost: 0.0019, Doğrulama Cost: 0.0026
# Epoch 1100/1500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0022
# Epoch 1200/1500, Eğitim Cost: 0.0013, Doğrulama Cost: 0.0019
# Epoch 1300/1500, Eğitim Cost: 0.0011, Doğrulama Cost: 0.0016
# Epoch 1400/1500, Eğitim Cost: 0.0010, Doğrulama Cost: 0.0015
# Epoch 0/2500, Eğitim Cost: 0.0923, Doğrulama Cost: 0.0822
# Epoch 100/2500, Eğitim Cost: 0.0591, Doğrulama Cost: 0.0712
# Epoch 200/2500, Eğitim Cost: 0.0497, Doğrulama Cost: 0.0606
# Epoch 300/2500, Eğitim Cost: 0.0427, Doğrulama Cost: 0.0521
# Epoch 400/2500, Eğitim Cost: 0.0371, Doğrulama Cost: 0.0453
# Epoch 500/2500, Eğitim Cost: 0.0323, Doğrulama Cost: 0.0396
# Epoch 600/2500, Eğitim Cost: 0.0283, Doğrulama Cost: 0.0346
# Epoch 700/2500, Eğitim Cost: 0.0248, Doğrulama Cost: 0.0303
# Epoch 800/2500, Eğitim Cost: 0.0217, Doğrulama Cost: 0.0265
# Epoch 900/2500, Eğitim Cost: 0.0189, Doğrulama Cost: 0.0230
# Epoch 1000/2500, Eğitim Cost: 0.0163, Doğrulama Cost: 0.0198
# Epoch 1100/2500, Eğitim Cost: 0.0139, Doğrulama Cost: 0.0168
# Epoch 1200/2500, Eğitim Cost: 0.0117, Doğrulama Cost: 0.0143
# Epoch 1300/2500, Eğitim Cost: 0.0099, Doğrulama Cost: 0.0120
# Epoch 1400/2500, Eğitim Cost: 0.0083, Doğrulama Cost: 0.0101
# Epoch 1500/2500, Eğitim Cost: 0.0070, Doğrulama Cost: 0.0085
# Epoch 1600/2500, Eğitim Cost: 0.0058, Doğrulama Cost: 0.0072
# Epoch 1700/2500, Eğitim Cost: 0.0049, Doğrulama Cost: 0.0061
# Epoch 1800/2500, Eğitim Cost: 0.0042, Doğrulama Cost: 0.0053
# Epoch 1900/2500, Eğitim Cost: 0.0036, Doğrulama Cost: 0.0046
# Epoch 2000/2500, Eğitim Cost: 0.0032, Doğrulama Cost: 0.0041
# Epoch 2100/2500, Eğitim Cost: 0.0029, Doğrulama Cost: 0.0037
# Epoch 2200/2500, Eğitim Cost: 0.0026, Doğrulama Cost: 0.0034
# Epoch 2300/2500, Eğitim Cost: 0.0024, Doğrulama Cost: 0.0032
# Epoch 2400/2500, Eğitim Cost: 0.0023, Doğrulama Cost: 0.0030
# Epoch 0/2500, Eğitim Cost: 0.2174, Doğrulama Cost: 0.1747
# Epoch 100/2500, Eğitim Cost: 0.0410, Doğrulama Cost: 0.0481
# Epoch 200/2500, Eğitim Cost: 0.0326, Doğrulama Cost: 0.0388
# Epoch 300/2500, Eğitim Cost: 0.0258, Doğrulama Cost: 0.0303
# Epoch 400/2500, Eğitim Cost: 0.0202, Doğrulama Cost: 0.0235
# Epoch 500/2500, Eğitim Cost: 0.0157, Doğrulama Cost: 0.0181
# Epoch 600/2500, Eğitim Cost: 0.0123, Doğrulama Cost: 0.0140
# Epoch 700/2500, Eğitim Cost: 0.0096, Doğrulama Cost: 0.0110
# Epoch 800/2500, Eğitim Cost: 0.0077, Doğrulama Cost: 0.0087
# Epoch 900/2500, Eğitim Cost: 0.0062, Doğrulama Cost: 0.0071
# Epoch 1000/2500, Eğitim Cost: 0.0052, Doğrulama Cost: 0.0059
# Epoch 1100/2500, Eğitim Cost: 0.0044, Doğrulama Cost: 0.0051
# Epoch 1200/2500, Eğitim Cost: 0.0038, Doğrulama Cost: 0.0044
# Epoch 1300/2500, Eğitim Cost: 0.0034, Doğrulama Cost: 0.0040
# Epoch 1400/2500, Eğitim Cost: 0.0030, Doğrulama Cost: 0.0036
# Epoch 1500/2500, Eğitim Cost: 0.0028, Doğrulama Cost: 0.0033
# Epoch 1600/2500, Eğitim Cost: 0.0026, Doğrulama Cost: 0.0031
# Epoch 1700/2500, Eğitim Cost: 0.0024, Doğrulama Cost: 0.0030
# Epoch 1800/2500, Eğitim Cost: 0.0023, Doğrulama Cost: 0.0029
# Epoch 1900/2500, Eğitim Cost: 0.0022, Doğrulama Cost: 0.0028
# Epoch 2000/2500, Eğitim Cost: 0.0021, Doğrulama Cost: 0.0027
# Epoch 2100/2500, Eğitim Cost: 0.0021, Doğrulama Cost: 0.0027
# Epoch 2200/2500, Eğitim Cost: 0.0020, Doğrulama Cost: 0.0026
# Epoch 2300/2500, Eğitim Cost: 0.0020, Doğrulama Cost: 0.0026
# Epoch 2400/2500, Eğitim Cost: 0.0019, Doğrulama Cost: 0.0026
# Epoch 0/2500, Eğitim Cost: 0.1177, Doğrulama Cost: 0.0941
# Epoch 100/2500, Eğitim Cost: 0.0458, Doğrulama Cost: 0.0558
# Epoch 200/2500, Eğitim Cost: 0.0384, Doğrulama Cost: 0.0493
# Epoch 300/2500, Eğitim Cost: 0.0320, Doğrulama Cost: 0.0413
# Epoch 400/2500, Eğitim Cost: 0.0256, Doğrulama Cost: 0.0328
# Epoch 500/2500, Eğitim Cost: 0.0195, Doğrulama Cost: 0.0249
# Epoch 600/2500, Eğitim Cost: 0.0144, Doğrulama Cost: 0.0183
# Epoch 700/2500, Eğitim Cost: 0.0104, Doğrulama Cost: 0.0133
# Epoch 800/2500, Eğitim Cost: 0.0074, Doğrulama Cost: 0.0096
# Epoch 900/2500, Eğitim Cost: 0.0054, Doğrulama Cost: 0.0069
# Epoch 1000/2500, Eğitim Cost: 0.0039, Doğrulama Cost: 0.0052
# Epoch 1100/2500, Eğitim Cost: 0.0029, Doğrulama Cost: 0.0039
# Epoch 1200/2500, Eğitim Cost: 0.0022, Doğrulama Cost: 0.0030
# Epoch 1300/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0024
# Epoch 1400/2500, Eğitim Cost: 0.0014, Doğrulama Cost: 0.0020
# Epoch 1500/2500, Eğitim Cost: 0.0011, Doğrulama Cost: 0.0016
# Epoch 1600/2500, Eğitim Cost: 0.0010, Doğrulama Cost: 0.0014
# Epoch 1700/2500, Eğitim Cost: 0.0008, Doğrulama Cost: 0.0012
# Epoch 1800/2500, Eğitim Cost: 0.0007, Doğrulama Cost: 0.0011
# Epoch 1900/2500, Eğitim Cost: 0.0007, Doğrulama Cost: 0.0010
# Epoch 2000/2500, Eğitim Cost: 0.0006, Doğrulama Cost: 0.0009
# Epoch 2100/2500, Eğitim Cost: 0.0006, Doğrulama Cost: 0.0009
# Epoch 2200/2500, Eğitim Cost: 0.0006, Doğrulama Cost: 0.0008
# Epoch 2300/2500, Eğitim Cost: 0.0005, Doğrulama Cost: 0.0008
# Epoch 2400/2500, Eğitim Cost: 0.0005, Doğrulama Cost: 0.0008
# Epoch 0/500, Eğitim Cost: 0.1089, Doğrulama Cost: 0.0788
# Epoch 100/500, Eğitim Cost: 0.0464, Doğrulama Cost: 0.0638
# Epoch 200/500, Eğitim Cost: 0.0464, Doğrulama Cost: 0.0638
# Epoch 300/500, Eğitim Cost: 0.0464, Doğrulama Cost: 0.0638
# Epoch 400/500, Eğitim Cost: 0.0464, Doğrulama Cost: 0.0638
# Epoch 0/500, Eğitim Cost: 0.1320, Doğrulama Cost: 0.0747
# Epoch 100/500, Eğitim Cost: 0.0072, Doğrulama Cost: 0.0080
# Epoch 200/500, Eğitim Cost: 0.0023, Doğrulama Cost: 0.0029
# Epoch 300/500, Eğitim Cost: 0.0018, Doğrulama Cost: 0.0025
# Epoch 400/500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 0/500, Eğitim Cost: 0.1579, Doğrulama Cost: 0.0549
# Epoch 100/500, Eğitim Cost: 0.0010, Doğrulama Cost: 0.0015
# Epoch 200/500, Eğitim Cost: 0.0005, Doğrulama Cost: 0.0008
# Epoch 300/500, Eğitim Cost: 0.0005, Doğrulama Cost: 0.0008
# Epoch 400/500, Eğitim Cost: 0.0004, Doğrulama Cost: 0.0007
# Epoch 0/1500, Eğitim Cost: 0.0858, Doğrulama Cost: 0.1016
# Epoch 100/1500, Eğitim Cost: 0.0224, Doğrulama Cost: 0.0272
# Epoch 200/1500, Eğitim Cost: 0.0040, Doğrulama Cost: 0.0051
# Epoch 300/1500, Eğitim Cost: 0.0019, Doğrulama Cost: 0.0027
# Epoch 400/1500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 500/1500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 600/1500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 700/1500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 800/1500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 900/1500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 1000/1500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 1100/1500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 1200/1500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 1300/1500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0025
# Epoch 1400/1500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0025
# Epoch 0/1500, Eğitim Cost: 0.1872, Doğrulama Cost: 0.0707
# Epoch 100/1500, Eğitim Cost: 0.0033, Doğrulama Cost: 0.0042
# Epoch 200/1500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 300/1500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0025
# Epoch 400/1500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0025
# Epoch 500/1500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0025
# Epoch 600/1500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0025
# Epoch 700/1500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0025
# Epoch 800/1500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0025
# Epoch 900/1500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0025
# Epoch 1000/1500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0025
# Epoch 1100/1500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0025
# Epoch 1200/1500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0025
# Epoch 1300/1500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0025
# Epoch 1400/1500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0025
# Epoch 0/1500, Eğitim Cost: 0.0847, Doğrulama Cost: 0.0971
# Epoch 100/1500, Eğitim Cost: 0.0076, Doğrulama Cost: 0.0088
# Epoch 200/1500, Eğitim Cost: 0.0020, Doğrulama Cost: 0.0027
# Epoch 300/1500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0024
# Epoch 400/1500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0024
# Epoch 500/1500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0024
# Epoch 600/1500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0024
# Epoch 700/1500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0024
# Epoch 800/1500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0023
# Epoch 900/1500, Eğitim Cost: 0.0015, Doğrulama Cost: 0.0023
# Epoch 1000/1500, Eğitim Cost: 0.0015, Doğrulama Cost: 0.0023
# Epoch 1100/1500, Eğitim Cost: 0.0015, Doğrulama Cost: 0.0023
# Epoch 1200/1500, Eğitim Cost: 0.0015, Doğrulama Cost: 0.0022
# Epoch 1300/1500, Eğitim Cost: 0.0014, Doğrulama Cost: 0.0022
# Epoch 1400/1500, Eğitim Cost: 0.0014, Doğrulama Cost: 0.0021
# Epoch 0/2500, Eğitim Cost: 0.3323, Doğrulama Cost: 0.1408
# Epoch 100/2500, Eğitim Cost: 0.0046, Doğrulama Cost: 0.0049
# Epoch 200/2500, Eğitim Cost: 0.0021, Doğrulama Cost: 0.0027
# Epoch 300/2500, Eğitim Cost: 0.0019, Doğrulama Cost: 0.0025
# Epoch 400/2500, Eğitim Cost: 0.0018, Doğrulama Cost: 0.0025
# Epoch 500/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 600/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 700/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 800/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 900/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 1000/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 1100/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 1200/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 1300/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 1400/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 1500/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 1600/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 1700/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 1800/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 1900/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 2000/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 2100/2500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0025
# Epoch 2200/2500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0025
# Epoch 2300/2500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0025
# Epoch 2400/2500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0025
# Epoch 0/2500, Eğitim Cost: 0.1181, Doğrulama Cost: 0.0799
# Epoch 100/2500, Eğitim Cost: 0.0116, Doğrulama Cost: 0.0134
# Epoch 200/2500, Eğitim Cost: 0.0026, Doğrulama Cost: 0.0033
# Epoch 300/2500, Eğitim Cost: 0.0019, Doğrulama Cost: 0.0026
# Epoch 400/2500, Eğitim Cost: 0.0018, Doğrulama Cost: 0.0025
# Epoch 500/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 600/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 700/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 800/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 900/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 1000/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 1100/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 1200/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 1300/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 1400/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 1500/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 1600/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 1700/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 1800/2500, Eğitim Cost: 0.0017, Doğrulama Cost: 0.0025
# Epoch 1900/2500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0025
# Epoch 2000/2500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0025
# Epoch 2100/2500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0025
# Epoch 2200/2500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0025
# Epoch 2300/2500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0025
# Epoch 2400/2500, Eğitim Cost: 0.0016, Doğrulama Cost: 0.0025
# Epoch 0/2500, Eğitim Cost: 0.0791, Doğrulama Cost: 0.0909
# Epoch 100/2500, Eğitim Cost: 0.0089, Doğrulama Cost: 0.0113
# Epoch 200/2500, Eğitim Cost: 0.0009, Doğrulama Cost: 0.0015
# Epoch 300/2500, Eğitim Cost: 0.0005, Doğrulama Cost: 0.0010
# Epoch 400/2500, Eğitim Cost: 0.0005, Doğrulama Cost: 0.0010
# Epoch 500/2500, Eğitim Cost: 0.0005, Doğrulama Cost: 0.0010
# Epoch 600/2500, Eğitim Cost: 0.0004, Doğrulama Cost: 0.0010
# Epoch 700/2500, Eğitim Cost: 0.0004, Doğrulama Cost: 0.0010
# Epoch 800/2500, Eğitim Cost: 0.0004, Doğrulama Cost: 0.0009
# Epoch 900/2500, Eğitim Cost: 0.0004, Doğrulama Cost: 0.0009
# Epoch 1000/2500, Eğitim Cost: 0.0004, Doğrulama Cost: 0.0009
# Epoch 1100/2500, Eğitim Cost: 0.0004, Doğrulama Cost: 0.0009
# Epoch 1200/2500, Eğitim Cost: 0.0004, Doğrulama Cost: 0.0009
# Epoch 1300/2500, Eğitim Cost: 0.0004, Doğrulama Cost: 0.0009
# Epoch 1400/2500, Eğitim Cost: 0.0004, Doğrulama Cost: 0.0009
# Epoch 1500/2500, Eğitim Cost: 0.0004, Doğrulama Cost: 0.0009
# Epoch 1600/2500, Eğitim Cost: 0.0004, Doğrulama Cost: 0.0009
# Epoch 1700/2500, Eğitim Cost: 0.0004, Doğrulama Cost: 0.0009
# Epoch 1800/2500, Eğitim Cost: 0.0004, Doğrulama Cost: 0.0009
# Epoch 1900/2500, Eğitim Cost: 0.0004, Doğrulama Cost: 0.0009
# Epoch 2000/2500, Eğitim Cost: 0.0004, Doğrulama Cost: 0.0009
# Epoch 2100/2500, Eğitim Cost: 0.0004, Doğrulama Cost: 0.0009
# Epoch 2200/2500, Eğitim Cost: 0.0004, Doğrulama Cost: 0.0008
# Epoch 2300/2500, Eğitim Cost: 0.0004, Doğrulama Cost: 0.0008
# Epoch 2400/2500, Eğitim Cost: 0.0004, Doğrulama Cost: 0.0008
# Epoch 0/500, Eğitim Cost: 0.1074, Doğrulama Cost: 0.0763
# Epoch 100/500, Eğitim Cost: 0.0111, Doğrulama Cost: 0.0144
# Epoch 200/500, Eğitim Cost: 0.0008, Doğrulama Cost: 0.0016
# Epoch 300/500, Eğitim Cost: 0.0005, Doğrulama Cost: 0.0010
# Epoch 400/500, Eğitim Cost: 0.0005, Doğrulama Cost: 0.0009
# En İyi Modelin Test Cost'u: 0.0009
# En İyi Hiperparametreler: {'learning_rate': 0.1, 'epochs': 500, 'hidden_size': 8}
# R² Skoru: 0.9846

# %%
import numpy as np
import pickle

# Eğitilmiş modeli yükle
with open("best_model.pkl", "rb") as file:
    NN = pickle.load(file)

print("Eğitilmiş model başarıyla yüklendi!")

# Girişlerin minimum ve maksimum değerlerini belirle
X_min = np.array([1, 1])  # Her iki çarpan için minimum değer
X_max = np.array([10, 10])  # Her iki çarpan için maksimum değer

# Çıktının minimum ve maksimum değerleri
Y_min = 1  # Minimum çarpım (1x1)
Y_max = 100  # Maksimum çarpım (10x10)

# Kullanıcı girdisi
print("Girmek istediğiniz sayıları girin:")
a = float(input("Birinci sayıyı girin: "))
b = float(input("İkinci sayıyı girin: "))

# Kullanıcı girdilerini normalize et
Z = np.array([[a, b]])
Z_normalized = (Z - X_min) / (X_max - X_min)  # Normalize işlemi

# Modelden tahmin al
prediction_normalized = NN.predict(Z_normalized)
prediction = prediction_normalized * (Y_max - Y_min) + Y_min  # Çıkışı geri ölçeklendir

# Sonuçları yazdır
print(f"Gerçek değer: {a * b}")
print(f"Çarpım Tahmini: {prediction[0]}")
# Out:
# Eğitilmiş model başarıyla yüklendi!
# Girmek istediğiniz sayıları girin:
# Birinci sayıyı girin: 9
# İkinci sayıyı girin: 8
# Gerçek değer: 72.0
# Çarpım Tahmini: [71.38889883]

# %%
# Ortalama Mutlak Hata (Mean Absolute Error - MAE)
mae = np.mean(np.abs(predictions - y_test.reshape(-1, 1)))
print(f"Ortalama Mutlak Hata (MAE): {mae:.4f}")
# Out:
# Ortalama Mutlak Hata (MAE): 0.0220
